# %%
#1.Read in the data
import pandas as pd
import numpy as np

df = pd.read_csv('/Users/emmasun/Desktop/1030/project/credit_score.csv')

print(df.shape)
df.head()
# Out:
# (45528, 19)
#   customer_id            name  age gender owns_car owns_house  no_of_children  \
# 0  CST_115179        ita Bose   46      F        N          Y             0.0
# 1  CST_121920  Alper Jonathan   29      M        N          Y             0.0
# 2  CST_109330     Umesh Desai   37      M        N          Y             0.0
# 3  CST_128288             Rie   39      F        N          Y             0.0
# 4  CST_151355          McCool   46      M        Y          Y             0.0
#
#    net_yearly_income  no_of_days_employed occupation_type  \
# 0          107934.04                612.0         Unknown
# 1          109862.62               2771.0        Laborers
# 2          230153.17                204.0        Laborers
# 3          122325.82              11941.0      Core staff
# 4          387286.00               1459.0      Core staff
#
#    total_family_members  migrant_worker  yearly_debt_payments  credit_limit  \
# ...

# %%
#2.EDA_data type
print(df.dtypes)
# Out:
# customer_id                 object
# name                        object
# age                          int64
# gender                      object
# owns_car                    object
# owns_house                  object
# no_of_children             float64
# net_yearly_income          float64
# no_of_days_employed        float64
# occupation_type             object
# total_family_members       float64
# migrant_worker             float64
# yearly_debt_payments       float64
# credit_limit               float64
# credit_limit_used(%)         int64
# credit_score               float64
# prev_defaults                int64
# default_in_last_6months      int64
# credit_card_default          int64
# dtype: object

# %%
#3.EDA_target variable_credit score is continuous
print(df['credit_card_default'].value_counts())
# Out:
# 0    41831
# 1     3697
# Name: credit_card_default, dtype: int64

# %%
#4.EDA_visualize target variable
import matplotlib
from matplotlib import pylab as plt

plt.figure(figsize=(5,3))
pd.value_counts(df['credit_card_default'],normalize=True).plot.barh()
plt.xlabel('fraction')
plt.ylabel('Credit Card Default')

plt.title('Credit Card Default Barplot')
plt.show()

# %%
print(df['occupation_type'].value_counts())
# Out:
# Unknown                  14299
# Laborers                  8134
# Sales staff               4725
# Core staff                4062
# Managers                  3168
# Drivers                   2747
# High skill tech staff     1682
# Accountants               1474
# Medicine staff            1275
# Security staff            1025
# Cooking staff              902
# Cleaning staff             665
# Private service staff      387
# Low-skill Laborers         336
# Waiters/barmen staff       203
# Secretaries                199
# Realty agents              101
# HR staff                    78
# IT staff                    66
# Name: occupation_type, dtype: int64

# %%
print(df['gender'].value_counts())
# Out:
# F      29957
# M      15570
# XNA        1
# Name: gender, dtype: int64

# %%
print(df['owns_car'].value_counts())
# Out:
# N    29743
# Y    15238
# Name: owns_car, dtype: int64

# %%
print(df['owns_house'].value_counts())
# Out:
# Y    31642
# N    13886
# Name: owns_house, dtype: int64

# %%
print(df['migrant_worker'].value_counts())
# Out:
# 0.0    37302
# 1.0     8139
# Name: migrant_worker, dtype: int64

# %%
print(df['no_of_children'].value_counts())
# Out:
# 0.0    31241
# 1.0     8985
# 2.0     3862
# 3.0      584
# 4.0       60
# 5.0       13
# 6.0        6
# 7.0        1
# 8.0        1
# 9.0        1
# Name: no_of_children, dtype: int64

# %%
print(df['total_family_members'].value_counts())
# Out:
# 2.0     23455
# 1.0      9913
# 3.0      7812
# 4.0      3623
# 5.0       564
# 6.0        57
# 7.0        12
# 8.0         6
# 10.0        2
# 9.0         1
# Name: total_family_members, dtype: int64

# %%
print(df['credit_score'].describe())
# Out:
# count    45520.000000
# mean       782.791257
# std        100.619746
# min        500.000000
# 25%        704.000000
# 50%        786.000000
# 75%        867.000000
# max        949.000000
# Name: credit_score, dtype: float64

# %%
print(df['prev_defaults'].describe())
# Out:
# count    45528.000000
# mean         0.060710
# std          0.264629
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          2.000000
# Name: prev_defaults, dtype: float64

# %%
print(df['default_in_last_6months'].describe())
# Out:
# count    45528.000000
# mean         0.050540
# std          0.219059
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: default_in_last_6months, dtype: float64

# %%
print(df['net_yearly_income'].describe())
# Out:
# count    4.552800e+04
# mean     2.006556e+05
# std      6.690740e+05
# min      2.717061e+04
# 25%      1.263458e+05
# 50%      1.717149e+05
# 75%      2.406038e+05
# max      1.407590e+08
# Name: net_yearly_income, dtype: float64

# %%
print(df['no_of_days_employed'].describe())
# Out:
# count     45065.000000
# mean      67609.289293
# std      139323.524434
# min           2.000000
# 25%         936.000000
# 50%        2224.000000
# 75%        5817.000000
# max      365252.000000
# Name: no_of_days_employed, dtype: float64

# %%
print(df['yearly_debt_payments'].describe())
# Out:
# count     45433.000000
# mean      31796.965311
# std       17269.727234
# min        2237.470000
# 25%       19231.140000
# 50%       29081.650000
# 75%       40561.150000
# max      328112.860000
# Name: yearly_debt_payments, dtype: float64

# %%
print(df['credit_limit'].describe())
# Out:
# count    4.552800e+04
# mean     4.354842e+04
# std      1.487847e+05
# min      4.003140e+03
# 25%      2.397381e+04
# 50%      3.568804e+04
# 75%      5.343576e+04
# max      3.112997e+07
# Name: credit_limit, dtype: float64

# %%
#5.EDA_Find continuous features that strongly correlates 
#age
categories = df['credit_card_default'].unique()
bin_range = (df['age'].min(),df['age'].max())

plt.figure(figsize=(5,3))

for c in categories:
    plt.hist(df[df['credit_card_default']==c]['age'],alpha=0.5,label=c,range=bin_range,bins=20,density=True)
plt.legend()
plt.ylabel('fraction')
plt.xlabel('age')
plt.title('Credit Card Default correlation with Age')
plt.show()

# %%
#5.EDA_Find continuous features that strongly correlates 
#age
dataset = [df[df['credit_card_default']==1]['age'].values,
           df[df['credit_card_default']==0]['age'].values]

plt.figure(figsize=(5,3))

plt.violinplot(dataset = dataset)
plt.xticks([1,2],['Pay On Time','Past Due'])
plt.ylabel('age')
plt.title('Credit Card Default correlation with Age')
plt.show()

# %%
#5.EDA_Find continuous features that strongly correlates 
#net_yearly_income
dataset = [df[df['credit_card_default']==1]['net_yearly_income'].values,
           df[df['credit_card_default']==0]['net_yearly_income'].values]

plt.figure(figsize=(5,3))

plt.violinplot(dataset = dataset)

plt.yscale('log')

plt.xticks([1,2],['Pay On Time','Past Due'])
plt.ylabel('Net Yearly Income')
plt.title('Credit Card Default correlation with Net Yearly Income')
plt.show()

# %%
#5.EDA_Find continuous features that strongly correlates 
#no_of_days_employed
categories = df['credit_card_default'].unique()
bin_range = (df['no_of_days_employed'].min(),df['no_of_days_employed'].max())

plt.figure(figsize=(5,3))

for c in categories:
    plt.hist(df[df['credit_card_default']==c]['no_of_days_employed'],alpha=0.5,label=c,range=bin_range,bins=20,density=True)
plt.legend()
plt.ylabel('fraction')
plt.xscale('log')
plt.xlabel('Employment Days')
plt.title('Credit Card Default correlation with Number of Days Employment')
plt.show()

# %%
#5.EDA_Find continuous features that strongly correlates 
#yearly_debt_payments
categories = df['credit_card_default'].unique()
bin_range = (df['yearly_debt_payments'].min(),df['yearly_debt_payments'].max())

plt.figure(figsize=(6,3))

for c in categories:
    plt.hist((df[df['credit_card_default']==c]['yearly_debt_payments']),alpha=0.5,label=c,range=bin_range,bins=200,density=True)
plt.legend()
plt.ylabel('fraction')
plt.xscale('log')
plt.xlabel('Yearly Debt Payments')
plt.title('Credit Card Default correlation with Yearly Debt Payments')
plt.show()

# %%
#5.EDA_Find continuous features that strongly correlates 
#yearly_debt_payments
df[['yearly_debt_payments','credit_card_default']].boxplot(by='credit_card_default',figsize=(5,5))
plt.ylabel('Yearly Debt Payments')
plt.xlabel('Credit Card Default')
plt.show()

# %%
#5.EDA_Find continuous features that strongly correlates 
#credit_limit
dataset = [df[df['credit_card_default']==1]['credit_limit'].values,
           df[df['credit_card_default']==0]['credit_limit'].values]

plt.figure(figsize=(5,3))

plt.violinplot(dataset = dataset)

plt.yscale('log')

plt.xticks([1,2],['Pay On Time','Past Due'])
plt.ylabel('Credit Limit')
plt.title('Credit Card Default correlation with Credit Limit')
plt.show()

# %%
#5.EDA_Find continuous features that strongly correlates 
#credit_limit_used(%)
categories = df['credit_card_default'].unique()
bin_range = (df['credit_limit_used(%)'].min(),df['credit_limit_used(%)'].max())

plt.figure(figsize=(5,3))

for c in categories:
    plt.hist(df[df['credit_card_default']==c]['credit_limit_used(%)'],alpha=0.5,label=c,range=bin_range,bins=10,density=True)
plt.legend()
plt.ylabel('Fraction')
plt.xlabel('Credit Limit Used(%)')
plt.title('Credit Card Default correlation with Card Limit Usage')
plt.show()

# %%
#5.EDA_Find continuous features that strongly correlates 
#credit_score
categories = df['credit_card_default'].unique()
bin_range = (df['credit_score'].min(),df['credit_score'].max())

plt.figure(figsize=(5,3))

for c in categories:
    plt.hist(df[df['credit_card_default']==c]['credit_score'],alpha=0.5,label=c,range=bin_range,bins=10,density=True)
plt.legend()
plt.ylabel('Fraction')
plt.xlabel('Credit Score')
plt.title('Credit Card Default correlation with Credit Score')
plt.show()

# %%
#5.EDA_Find ordinal features that strongly correlates 
#prev_defaults
count_matrix = df.groupby(['prev_defaults', 'credit_card_default']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)

count_matrix_norm.plot(kind='bar', stacked=True,figsize=(5,3))
plt.ylabel('Fraction')
plt.legend(loc=4)
plt.title('Credit Card Default correlation with Previous Defaults')
plt.show()

# %%
#5.EDA_Find ordinal features that strongly correlates 
#default_in_last_6months
count_matrix = df.groupby(['default_in_last_6months', 'credit_card_default']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)

count_matrix_norm.plot(kind='bar', stacked=True,figsize=(5,3))
plt.ylabel('Fraction')
plt.legend(loc=4)
plt.title('Credit Card Default correlation with 6Months Defaults')
plt.show()

# %%
#5.EDA_Find ordinal features that strongly correlates 
#no_of_children
count_matrix = df.groupby(['no_of_children', 'credit_card_default']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)

count_matrix_norm.plot(kind='bar', stacked=True,figsize=(5,3))
plt.ylabel('Fraction')
plt.legend(loc=4)
plt.title('Credit Card Default correlation with Number of Children')
plt.show()

# %%
#5.EDA_Find ordinal features that strongly correlates 
#total_family_members
count_matrix = df.groupby(['total_family_members', 'credit_card_default']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)

count_matrix_norm.plot(kind='bar', stacked=True,figsize=(5,3))
plt.ylabel('Fraction')
plt.legend(loc=4)
plt.title('Credit Card Default correlation with Total Family Members')
plt.show()

# %%
#5.EDA_Find categorical features that strongly correlates 
#gender
count_matrix = df.groupby(['gender', 'credit_card_default']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)

count_matrix_norm.plot(kind='bar', stacked=True,figsize=(5,3))
plt.ylabel('Fraction')
plt.legend(loc=4)
plt.title('Credit Card Default correlation with Gender')
plt.show()

# %%
#5.EDA_Find categorical features that strongly correlates 
#owns_car
count_matrix = df.groupby(['owns_car', 'credit_card_default']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)

count_matrix_norm.plot(kind='bar', stacked=True,figsize=(5,3))
plt.ylabel('Fraction')
plt.legend(loc=4)
plt.title('Credit Card Default correlation with Movable Property')
plt.show()

# %%
#5.EDA_Find categorical features that strongly correlates 
#owns_house
count_matrix = df.groupby(['owns_house', 'credit_card_default']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)

count_matrix_norm.plot(kind='bar', stacked=True,figsize=(5,3))
plt.ylabel('Fraction')
plt.legend(loc=4)
plt.title('Credit Card Default correlation with Real Estate')
plt.show()

# %%
#5.EDA_Find categorical features that strongly correlates 
#migrant_worker
count_matrix = df.groupby(['migrant_worker', 'credit_card_default']).size().unstack()
count_matrix_norm = count_matrix.div(count_matrix.sum(axis=1),axis=0)

count_matrix_norm.plot(kind='bar', stacked=True,figsize=(5,3))
plt.ylabel('Fraction')
plt.legend(loc=4)
plt.title('Credit Card Default correlation with Immigrantion')
plt.show()

# %%
#6.missing value
# df.replace('',np.nan, inplace = True)
# df = df.replace(np.nan, inplace = True)

print('data dimensions:',df.shape)
perc_missing_per_ftr = df.isnull().sum(axis=0)/df.shape[0]
print('fraction of missing values in features:')
print(perc_missing_per_ftr[perc_missing_per_ftr >0])
print('data types of the features with missing values:')
print(df[perc_missing_per_ftr[perc_missing_per_ftr > 0].index].dtypes)
frac_missing = sum(df.isnull().sum(axis=1)!=0)/df.shape[0]
print('fraction of points with missing values:',frac_missing)
# Out:
# data dimensions: (45528, 19)
# fraction of missing values in features:
# owns_car                0.012015
# no_of_children          0.017001
# no_of_days_employed     0.010170
# total_family_members    0.001823
# migrant_worker          0.001911
# yearly_debt_payments    0.002087
# credit_score            0.000176
# dtype: float64
# data types of the features with missing values:
# owns_car                 object
# no_of_children          float64
# no_of_days_employed     float64
# total_family_members    float64
# migrant_worker          float64
# yearly_debt_payments    float64
# credit_score            float64
# dtype: object
# fraction of points with missing values: 0.04434633632050606

# %%
#7.split
y = df['credit_card_default']
customer_id = df['customer_id']
name = df['name']
X = df.drop(columns=['credit_card_default','customer_id','name'])
classes, counts = np.unique(y,return_counts=True)
print(classes, counts)
print('balance:',np.max(counts/len(y)))
# Out:
# [0 1] [41831  3697]
# balance: 0.9187972236865226

# %%
#7.split
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import StratifiedKFold

random_state = 42

X_other, X_test, y_other, y_test = train_test_split(X,y,test_size = 0.2,stratify=y,random_state=random_state)
print('test balance:',np.unique(y_test,return_counts=True))

kf = StratifiedKFold(n_splits=4,shuffle=True,random_state=random_state)
for train_index, val_index in kf.split(X_other,y_other):
    print('new fold')
    X_train = X_other.iloc[train_index]
    y_train = y_other.iloc[train_index]
    X_val = X_other.iloc[val_index]
    y_val = y_other.iloc[val_index]
    print(np.unique(y_train,return_counts=True))
    print(np.unique(y_val,return_counts=True))
# Out:
# test balance: (array([0, 1]), array([8367,  739]))
# new fold
# (array([0, 1]), array([25098,  2218]))
# (array([0, 1]), array([8366,  740]))
# new fold
# (array([0, 1]), array([25098,  2218]))
# (array([0, 1]), array([8366,  740]))
# new fold
# (array([0, 1]), array([25098,  2219]))
# (array([0, 1]), array([8366,  739]))
# new fold
# (array([0, 1]), array([25098,  2219]))
# (array([0, 1]), array([8366,  739]))

# %%
#8.preprocess data
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

#ordinal_ftrs = [] 
#ordinal_cats = []
onehot_ftrs = ['gender','owns_car','owns_house','no_of_children','occupation_type','total_family_members','migrant_worker']
minmax_ftrs = ['age','credit_limit_used(%)','credit_score','prev_defaults','default_in_last_6months']
std_ftrs = ['net_yearly_income','no_of_days_employed','yearly_debt_payments','credit_limit']

# collect all the encoders
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(sparse=False,handle_unknown='ignore'), onehot_ftrs),
        ('minmax', MinMaxScaler(), minmax_ftrs),
        ('std', StandardScaler(), std_ftrs)])

clf = Pipeline(steps=[('preprocessor', preprocessor)]) 

X_train_prep = clf.fit_transform(X_train)
X_val_prep = clf.transform(X_val)
X_test_prep = clf.transform(X_test)

print('X_train without preprocess:',X_train.shape)
print('X_train after preprocess:',X_train_prep.shape)
print(X_train_prep)
feature_names = preprocessor.get_feature_names_out()
df_test = pd.DataFrame(data = X_test_prep, columns = feature_names)
print(feature_names)
# Out:
# X_train without preprocess: (27317, 16)
# X_train after preprocess: (27317, 59)
# [[ 1.          0.          1.         ... -0.47616427 -1.39795419
#   -0.68419573]
#  [ 0.          1.          0.         ... -0.48041243  1.49165264
#   -0.09206214]
#  [ 0.          1.          1.         ... -0.47422286  1.01429432
#    2.59953491]
#  ...
#  [ 0.          1.          0.         ... -0.47866445 -1.24599876
#   -0.22927737]
#  [ 1.          0.          0.         ... -0.47584189  0.66953267
#    0.73946052]
#  [ 1.          0.          1.         ... -0.41941229 -1.14829626
#   -0.6696826 ]]
# ['onehot__gender_F' 'onehot__gender_M' 'onehot__owns_car_N'
#  'onehot__owns_car_Y' 'onehot__owns_car_nan' 'onehot__owns_house_N'
#  'onehot__owns_house_Y' 'onehot__no_of_children_0.0'
#  'onehot__no_of_children_1.0' 'onehot__no_of_children_2.0'
#  'onehot__no_of_children_3.0' 'onehot__no_of_children_4.0'
#  'onehot__no_of_children_5.0' 'onehot__no_of_children_6.0'
# ...
